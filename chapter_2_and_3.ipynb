# %%
import numpy as np

# %%
x = np.array([1,2,3])
w = np.array([0.2, .8, -0.5])
b = 2

output = x[0]*w[0] + x[1]*w[1] + x[2]*w[2] + b

print(output)
# Out:
# 2.3

# %%
# Out:
# array([[1, 2, 3, 4]])
